# %% [markdown]
# ### load stuff

# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

# %%
# read data 

train_df = pd.get_dummies(pd.read_csv('train.csv').drop(['Name', 'Ticket', 'Cabin'], axis=1))
test_df = pd.get_dummies(pd.read_csv('test.csv').drop(['Name', 'Ticket', 'Cabin'], axis=1))

# %% [markdown]
# ### Preprocessing / Cleaning

# %%
# impute missing data

val = train_df['Age'].mean()
train_df['Age'].fillna(val, inplace=True)
train_df.isnull().sum()
# Out:
# /tmp/ipykernel_6877/3123834085.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Age'].fillna(val, inplace=True)
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
# create training and target vectors

live = train_df['Survived']
train_df.drop('Survived', axis=1, inplace=True)

# %%
import scipy.stats as stats
train_df[(np.abs(stats.zscore(train_df)) < 3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'sqrt'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 import scipy.stats as stats
# ----> 2 train_df[(np.abs(stats.zscore(train_df)) < 3).all(axis=1)]
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:2924, in zscore(a, axis, ddof, nan_policy)
#    2842 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2843     """
#    2844     Compute the z score.
#    2845
#    (...)
#    2922            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2923     """
# -> 2924     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:3089, in zmap(scores, compare, axis, ddof, nan_policy)
#    3087 else:
#    3088     mn = a.mean(axis=axis, keepdims=True)
# -> 3089     std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    3090     # The intent is to check whether all elements of `a` along `axis` are
#    3091     # identical. Due to finite precision arithmetic, comparing elements
#    3092     # against `mn` doesn't work. Previously, this compared elements to
#    3093     # `_first`, but that extracts the element at index 0 regardless of
#    3094     # whether it is masked. As a simple fix, compare against `min`.
#    3095     a0 = a.min(axis=axis, keepdims=True)
#
# File ~/miniconda3/envs/venv/lib/python3.12/site-packages/numpy/core/_methods.py:210, in _std(a, axis, dtype, out, ddof, keepdims, where)
#     206 ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#     207            keepdims=keepdims, where=where)
#     209 if isinstance(ret, mu.ndarray):
# --> 210     ret = um.sqrt(ret, out=ret)
#     211 elif hasattr(ret, 'dtype'):
#     212     ret = ret.dtype.type(um.sqrt(ret))
#
# TypeError: loop of ufunc does not support argument 0 of type float which has no callable sqrt method

# %% [markdown]
# ### LinearSVC

# %%
# train LinearSVC

clf = make_pipeline(StandardScaler(), LinearSVC(random_state=0, tol=1e-5))
clf.fit(train_df, live)
# Out:
# /home/server/miniconda3/envs/venv/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/server/miniconda3/envs/venv/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearsvc', LinearSVC(random_state=0, tol=1e-05))])

# %%
# create predictions

val = test_df['Age'].mean()
test_df['Age'].fillna(val, inplace=True)

val = test_df['Fare'].mean()
test_df['Fare'].fillna(val, inplace=True)

predictions = clf.predict(test_df)
# Out:
# /tmp/ipykernel_6877/407314684.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Age'].fillna(val, inplace=True)
# /tmp/ipykernel_6877/407314684.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Fare'].fillna(val, inplace=True)

# %% [markdown]
# ### Format for submission

# %%
predictions_df = pd.DataFrame({'PassengerID': test_df[['PassengerId']].values[:, 0],
                              'Survived': predictions})
predictions_df.shape
# should be (418, 2)
# Out:
# (418, 2)

# %%
# write to csv
predictions_df.to_csv("submission.csv", index=False)
